# %%
base_covid <- read.csv("(2.2) WHO COVID-19 Global Table.csv", 
                       header = TRUE, 
                       sep = ",",
                       dec = ".")

head(base_covid, n = 5)
# Out:
#   ï..Name                  WHO.Region      Cases...cumulative.total
# 1 Global                                   190597409
# 2 United States of America Americas         33723155
# 3 India                    South-East Asia  31144229
# 4 Brazil                   Americas         19342448
# 5 Russian Federation       Europe            5982766
#   Cases...cumulative.total.per.100000.population
# 1  2445.268
# 2 10188.180
# 3  2256.820
# 4  9099.780
# 5  4099.630
#   Cases...newly.reported.in.last.7.days
# 1 3427304
# 2  208209
# 3  269853
# 4  273445
# 5  174293
#   Cases...newly.reported.in.last.7.days.per.100000.population
# 1  43.97057
# 2  62.90000
# 3  19.55000
# 4 128.64000
# 5 119.43000
#   Cases...newly.reported.in.last.24.hours Deaths...cumulative.total
# 1 427576                                  4093145
# 2      0                                   603790
# 3  38164                                   414108
# 4  34339                                   541266
# ...
