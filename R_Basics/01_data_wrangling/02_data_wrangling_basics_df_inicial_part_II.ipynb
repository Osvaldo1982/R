# %% [markdown]
# # Data Wrangling R
#
# Introdução ao pacote dplyr (https://dplyr.tidyverse.org/)

# %%
library(readxl)
library("tidyverse")
library(dplyr)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# v ggplot2 3.1.1       v purrr   0.3.2
# v tibble  2.1.1       v dplyr   0.8.0.1
# v tidyr   0.8.3       v stringr 1.4.0
# v readr   1.3.1       v forcats 0.4.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter()  masks stats::filter()
# x purrr::flatten() masks jsonlite::flatten()
# x dplyr::lag()     masks stats::lag()

# %% [markdown]
# # Dataset Inicial

# %% [markdown]
# ## Read Excel

# %%
dataset_inicial <- read_excel("(1.2) Dataset Aula Data Wrangling.xls")

head(dataset_inicial, n=5)
# Out:
#   Estudante   Tempo para chegar à escola (minutos)
# 1 Gabriela    15
# 2 Dalila      20
# 3 Gustavo     20
# 4 Letícia     40
# 5 Luiz Ovídio 50
#   Distância percorrida até a escola (quilômetros) Quantidade de semáforos
# 1  8                                              0
# 2  6                                              1
# 3 15                                              0
# 4 20                                              1
# 5 25                                              2
#   Período do dia Perfil ao volante
# 1 Manhã          calmo
# 2 Manhã          moderado
# 3 Manhã          moderado
# 4 Tarde          agressivo
# 5 Tarde          agressivo

# %% [markdown]
# ## Definindo novo cabeçalho

# %%
novos_nomes <- c("Observações",
                 "Tempo para chegar",
                 "Distância percorrida",
                 "Semáforos",
                 "Período",
                 "Perfil")

# 
names(dataset_inicial) <- novos_nomes

head(dataset_inicial, n=5)
# Out:
#   Observações Tempo para chegar Distância percorrida Semáforos Período
# 1 Gabriela    15                 8                   0         Manhã
# 2 Dalila      20                 6                   1         Manhã
# 3 Gustavo     20                15                   0         Manhã
# 4 Letícia     40                20                   1         Tarde
# 5 Luiz Ovídio 50                25                   2         Tarde
#   Perfil
# 1 calmo
# 2 moderado
# 3 moderado
# 4 agressivo
# 5 agressivo

# %% [markdown]
# ## Usando a função rename

# %%
nova_base <- rename(dataset_inicial, 
                    observacoes = Observações,
                    tempo = "Tempo para chegar",
                    distancia = "Distância percorrida",
                    semaforos = "Semáforos",
                    periodo = "Período",
                    perfil = "Perfil"
                   )

head(nova_base, n=5)
# Out:
#   observacoes tempo distancia semaforos periodo perfil
# 1 Gabriela    15     8        0         Manhã   calmo
# 2 Dalila      20     6        1         Manhã   moderado
# 3 Gustavo     20    15        0         Manhã   moderado
# 4 Letícia     40    20        1         Tarde   agressivo
# 5 Luiz Ovídio 50    25        2         Tarde   agressivo

# %% [markdown]
# ## Criando novo objeto dataframe

# %%
# 
nova_base_pipe <- nova_base %>% rename(obs = observacoes,
                                       temp = tempo,
                                       dist = distancia,
                                       sem = semaforos,
                                       per = periodo,
                                       perf = perfil)

nova_base_pipe
# Out:
#    obs         temp dist sem per   perf
# 1  Gabriela    15    8   0   Manhã calmo
# 2  Dalila      20    6   1   Manhã moderado
# 3  Gustavo     20   15   0   Manhã moderado
# 4  Letícia     40   20   1   Tarde agressivo
# 5  Luiz Ovídio 50   25   2   Tarde agressivo
# 6  Leonor      25   11   1   Manhã moderado
# 7  Ana         10    5   0   Manhã calmo
# 8  Antônio     55   32   3   Tarde calmo
# 9  Júlia       35   28   1   Manhã moderado
# 10 Mariana     30   20   1   Manhã moderado

# %% [markdown]
# ## Função select
#
# A seguir, com "select", informaremos a ordem (inclusive, excluindo variáveis)

# %%
head(nova_base, n=5)
# Out:
#   observacoes tempo distancia semaforos periodo perfil
# 1 Gabriela    15     8        0         Manhã   calmo
# 2 Dalila      20     6        1         Manhã   moderado
# 3 Gustavo     20    15        0         Manhã   moderado
# 4 Letícia     40    20        1         Tarde   agressivo
# 5 Luiz Ovídio 50    25        2         Tarde   agressivo

# %%
nova_base %>% select(tempo, semaforos, perfil, observacoes)
# Out:
#    tempo semaforos perfil    observacoes
# 1  15    0         calmo     Gabriela
# 2  20    1         moderado  Dalila
# 3  20    0         moderado  Gustavo
# 4  40    1         agressivo Letícia
# 5  50    2         agressivo Luiz Ovídio
# 6  25    1         moderado  Leonor
# 7  10    0         calmo     Ana
# 8  55    3         calmo     Antônio
# 9  35    1         moderado  Júlia
# 10 30    1         moderado  Mariana

# %% [markdown]
# # Função relocate
#
# O mesmo trabalho poderia ser feito com a função "relocate"

# %%
nova_base %>% relocate(perfil, .after = observacoes)
# Out:
# Error in relocate(., perfil, .after = observacoes): não foi possível encontrar a função "relocate"
# Traceback:
#
# 1. nova_base %>% relocate(perfil, .after = observacoes)
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. withVisible(function_list[[k]](value))
# 8. function_list[[k]](value)

# %%
nova_base %>% relocate(perfil, .before = tempo)
# Out:
# Error in relocate(., perfil, .before = tempo): não foi possível encontrar a função "relocate"
# Traceback:
#
# 1. nova_base %>% relocate(perfil, .before = tempo)
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. withVisible(function_list[[k]](value))
# 8. function_list[[k]](value)

# %%
nova_base
# Out:
#    observacoes tempo distancia semaforos periodo perfil
# 1  Gabriela    15     8        0         Manhã   calmo
# 2  Dalila      20     6        1         Manhã   moderado
# 3  Gustavo     20    15        0         Manhã   moderado
# 4  Letícia     40    20        1         Tarde   agressivo
# 5  Luiz Ovídio 50    25        2         Tarde   agressivo
# 6  Leonor      25    11        1         Manhã   moderado
# 7  Ana         10     5        0         Manhã   calmo
# 8  Antônio     55    32        3         Tarde   calmo
# 9  Júlia       35    28        1         Manhã   moderado
# 10 Mariana     30    20        1         Manhã   moderado

# %%
relocate(nova_base, tempo, .after = periodo)
# Out:
# Error in relocate(nova_base, tempo, .after = periodo): não foi possível encontrar a função "relocate"
# Traceback:

# %% [markdown]
# # Função pull
#
# A função "pull" executa trabalho semelhante ao "select", porém gera um vetor

# %%
vetor_pull <- nova_base %>% pull(var = 3)

vetor_pull
# Out:
#  [1]  8  6 15 20 25 11  5 32 28 20

# %% [markdown]
# # Função summarise
#
# Função "summarise": função que resume o dataset, podendo criar outros. No primeiro caso, abaixo, todas as observações são resumidas em descritivas

# %%
descritivas_nova_base <- summarise(nova_base,
                                   observações=n(),
                                   média=mean(tempo),
                                   mediana=median(tempo),
                                   desv_pad=sd(tempo),
                                   mínimo=min(tempo),
                                   máximo=max(tempo),
                                   quartil_3=quantile(tempo, type=5, 0.75))

descritivas_nova_base
# Out:
#   observações média mediana desv_pad mínimo máximo quartil_3
# 1 10          30    27.5    14.90712 10     55     40

# %% [markdown]
# # Função groupby
#
# Então, acima, criamos um data frame com uma linha de descritivas da variável. Poderia ser utilizada para criar informações mais específicas sobre o dataset. Para isto, o "summarise" é utilizado em conjunto com a função "group by". A seguir, vamos agrupar as informações do dataset pelo critério de "período".

# %%
nova_base
# Out:
#    observacoes tempo distancia semaforos periodo perfil
# 1  Gabriela    15     8        0         Manhã   calmo
# 2  Dalila      20     6        1         Manhã   moderado
# 3  Gustavo     20    15        0         Manhã   moderado
# 4  Letícia     40    20        1         Tarde   agressivo
# 5  Luiz Ovídio 50    25        2         Tarde   agressivo
# 6  Leonor      25    11        1         Manhã   moderado
# 7  Ana         10     5        0         Manhã   calmo
# 8  Antônio     55    32        3         Tarde   calmo
# 9  Júlia       35    28        1         Manhã   moderado
# 10 Mariana     30    20        1         Manhã   moderado

# %% [markdown]
# Porém, o "group by" fica registrado no objeto

# %%
base_grupo <- group_by(nova_base, periodo)

base_grupo
# Out:
#    observacoes tempo distancia semaforos periodo perfil
# 1  Gabriela    15     8        0         Manhã   calmo
# 2  Dalila      20     6        1         Manhã   moderado
# 3  Gustavo     20    15        0         Manhã   moderado
# 4  Letícia     40    20        1         Tarde   agressivo
# 5  Luiz Ovídio 50    25        2         Tarde   agressivo
# 6  Leonor      25    11        1         Manhã   moderado
# 7  Ana         10     5        0         Manhã   calmo
# 8  Antônio     55    32        3         Tarde   calmo
# 9  Júlia       35    28        1         Manhã   moderado
# 10 Mariana     30    20        1         Manhã   moderado

# %% [markdown]
# O resultado do "summarise" abaixo é para cada grupo especificado no objeto. Também criamos um data frame com duas linhas, uma para cada grupo. Caso queira retirar o agrupamento criado, basta aplicar o "ungroup".

# %%
descritivas_base_grupo <- base_grupo %>% summarise(média = mean(tempo),
                                                   desvio_pad=sd(tempo),
                                                   n_obs = n()
                                                   )

descritivas_base_grupo
# Out:
#   periodo média    desvio_pad n_obs
# 1 Manhã   22.14286 8.591247   7
# 2 Tarde   48.33333 7.637626   3

# %% [markdown]
# O resultado do "summarise" acima é para cada grupo especificado no objeto. Também criamos um data frame com duas linhas, uma para cada grupo. Caso queira retirar o agrupamento criado, basta aplicar o "ungroup".

# %%
base_sem_grupo <- base_grupo %>% ungroup () %>% droplevels(.)

# informações para a base completa
summarise(base_sem_grupo,
          mean(tempo)
         )
# Out:
#   mean(tempo)
# 1 30

# %% [markdown]
# A função "arrange" apenas fez a organização de apresentação do dataset. Foi pedido que fosse organizado de forma decrescente (desc). Se retirar o desc, fica na ordem crescente.

# %%
nova_base_grupos <- nova_base %>% group_by(periodo, perfil
                                          ) %>% 
                                                  summarise(tempo_médio = mean(tempo),
                                                            mínimo = min(tempo),
                                                            máximo = max(tempo),
                                                            contagem = n()
                                                           ) %>% 
                                                  arrange(desc(máximo))

nova_base_grupos
# Out:
#   periodo perfil    tempo_médio mínimo máximo contagem
# 1 Tarde   calmo     55.0        55     55     1
# 2 Tarde   agressivo 45.0        40     50     2
# 3 Manhã   moderado  26.0        20     35     5
# 4 Manhã   calmo     12.5        10     15     2

# %% [markdown]
# # Função filter
#
# A função "filter" tem o objetivo de gerar subconjuntos do dataset. São especificados os critérios e as linhas que os atenderem serão filtradas. Os principais operadores lógicos são:
#
# * ==: igual
# * !=: diferente
# * Os símbolos > e <: maior e menor (podem conter o igual >= e <=)
# * &: indica "E"
# * | : indica "OU"
#
# ## Sem função filter
#
# Inicialmente, sem utilizar a função, poderia ser feito:

# %%
# critérios antes da vírgula
filtro_1 <- nova_base[nova_base$tempo > 20,] 

filtro_1
# Out:
#   observacoes tempo distancia semaforos periodo perfil
# 1 Letícia     40    20        1         Tarde   agressivo
# 2 Luiz Ovídio 50    25        2         Tarde   agressivo
# 3 Leonor      25    11        1         Manhã   moderado
# 4 Antônio     55    32        3         Tarde   calmo
# 5 Júlia       35    28        1         Manhã   moderado
# 6 Mariana     30    20        1         Manhã   moderado

# %%
filtro_2 <- nova_base[nova_base$tempo > 20 & nova_base$distancia < 25,]

filtro_2
# Out:
#   observacoes tempo distancia semaforos periodo perfil
# 1 Letícia     40    20        1         Tarde   agressivo
# 2 Leonor      25    11        1         Manhã   moderado
# 3 Mariana     30    20        1         Manhã   moderado

# %%
filtro_5 <- nova_base[nova_base$tempo <=15 | nova_base$periodo == "Tarde",]

filtro_5
# Out:
#   observacoes tempo distancia semaforos periodo perfil
# 1 Gabriela    15     8        0         Manhã   calmo
# 2 Letícia     40    20        1         Tarde   agressivo
# 3 Luiz Ovídio 50    25        2         Tarde   agressivo
# 4 Ana         10     5        0         Manhã   calmo
# 5 Antônio     55    32        3         Tarde   calmo

# %% [markdown]
# ## Usando a função filter

# %%
base_filtro_1 <- filter(nova_base, tempo > 20)

base_filtro_1
# Out:
#   observacoes tempo distancia semaforos periodo perfil
# 1 Letícia     40    20        1         Tarde   agressivo
# 2 Luiz Ovídio 50    25        2         Tarde   agressivo
# 3 Leonor      25    11        1         Manhã   moderado
# 4 Antônio     55    32        3         Tarde   calmo
# 5 Júlia       35    28        1         Manhã   moderado
# 6 Mariana     30    20        1         Manhã   moderado

# %%
base_filtro_2 <- filter(nova_base, tempo > 20 & distancia < 25)

base_filtro_2
# Out:
#   observacoes tempo distancia semaforos periodo perfil
# 1 Letícia     40    20        1         Tarde   agressivo
# 2 Leonor      25    11        1         Manhã   moderado
# 3 Mariana     30    20        1         Manhã   moderado

# %%
base_filtro_3 <- filter(nova_base, periodo == "Manhã")

base_filtro_3
# Out:
#   observacoes tempo distancia semaforos periodo perfil
# 1 Gabriela    15     8        0         Manhã   calmo
# 2 Dalila      20     6        1         Manhã   moderado
# 3 Gustavo     20    15        0         Manhã   moderado
# 4 Leonor      25    11        1         Manhã   moderado
# 5 Ana         10     5        0         Manhã   calmo
# 6 Júlia       35    28        1         Manhã   moderado
# 7 Mariana     30    20        1         Manhã   moderado

# %%
base_filtro_4 <- filter(nova_base, periodo != "Manhã" & between(tempo, 20, 50))

base_filtro_4
# Out:
#   observacoes tempo distancia semaforos periodo perfil
# 1 Letícia     40    20        1         Tarde   agressivo
# 2 Luiz Ovídio 50    25        2         Tarde   agressivo

# %%
base_filtro_5 <- filter(nova_base, tempo <= 15 | periodo == "Tarde")

base_filtro_5
# Out:
#   observacoes tempo distancia semaforos periodo perfil
# 1 Gabriela    15     8        0         Manhã   calmo
# 2 Letícia     40    20        1         Tarde   agressivo
# 3 Luiz Ovídio 50    25        2         Tarde   agressivo
# 4 Ana         10     5        0         Manhã   calmo
# 5 Antônio     55    32        3         Tarde   calmo

# %%
# base_filtro_6: observações tempo > 30 (média geral) foram filtradas
base_filtro_6 <- filter(nova_base, tempo > mean(tempo, na.rm = TRUE))

base_filtro_6
# Out:
#   observacoes tempo distancia semaforos periodo perfil
# 1 Letícia     40    20        1         Tarde   agressivo
# 2 Luiz Ovídio 50    25        2         Tarde   agressivo
# 3 Antônio     55    32        3         Tarde   calmo
# 4 Júlia       35    28        1         Manhã   moderado

# %% [markdown]
# ## Função filter com groupby
#
# A função filter também pode ser aplicada em datasets com grupos (group by). Neste caso, a função é aplicada dentro de cada grupo.

# %%
base_filtro_7 <- nova_base %>% group_by(periodo) %>% 
                                                      filter(tempo > mean(tempo, na.rm=TRUE)
                                                            ) %>% 
                                                      ungroup () %>% droplevels(.)

base_filtro_7
# Out:
#   observacoes tempo distancia semaforos periodo perfil
# 1 Luiz Ovídio 50    25        2         Tarde   agressivo
# 2 Leonor      25    11        1         Manhã   moderado
# 3 Antônio     55    32        3         Tarde   calmo
# 4 Júlia       35    28        1         Manhã   moderado
# 5 Mariana     30    20        1         Manhã   moderado

# %% [markdown]
# # Função slice

# %%
# com base na posição das linhas
nova_base %>% slice(5:9)
# Out:
#   observacoes tempo distancia semaforos periodo perfil
# 1 Luiz Ovídio 50    25        2         Tarde   agressivo
# 2 Leonor      25    11        1         Manhã   moderado
# 3 Ana         10     5        0         Manhã   calmo
# 4 Antônio     55    32        3         Tarde   calmo
# 5 Júlia       35    28        1         Manhã   moderado

# %%
# as três primeiras linhas
nova_base %>% slice_head(n=3)
# Out:
# Error in slice_head(., n = 3): não foi possível encontrar a função "slice_head"
# Traceback:
#
# 1. nova_base %>% slice_head(n = 3)
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. withVisible(function_list[[k]](value))
# 8. function_list[[k]](value)

# %%
# as três últimas linhas
nova_base %>% slice_tail(n=3)

# %%
# os prop % menores
nova_base %>% slice_min(order_by = distancia, prop = 0.40)
# Out:
# Error in slice_min(., order_by = distancia, prop = 0.4): não foi possível encontrar a função "slice_min"
# Traceback:
#
# 1. nova_base %>% slice_min(order_by = distancia, prop = 0.4)
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. withVisible(function_list[[k]](value))
# 8. function_list[[k]](value)

# %%
# os prop % maiores
nova_base %>% slice_max(order_by = distancia, prop = 0.10)
# Out:
# Error in slice_max(., order_by = distancia, prop = 0.1): não foi possível encontrar a função "slice_max"
# Traceback:
#
# 1. nova_base %>% slice_max(order_by = distancia, prop = 0.1)
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. withVisible(function_list[[k]](value))
# 8. function_list[[k]](value)
