# %%
library(readxl)
library("tidyverse")
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# v ggplot2 3.1.1       v purrr   0.3.2
# v tibble  2.1.1       v dplyr   0.8.0.1
# v tidyr   0.8.3       v stringr 1.4.0
# v readr   1.3.1       v forcats 0.4.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter()  masks stats::filter()
# x purrr::flatten() masks jsonlite::flatten()
# x dplyr::lag()     masks stats::lag()

# %% [markdown]
# # Dataset inicial

# %%
dataset_inicial <- read_excel("(1.2) Dataset Aula Data Wrangling.xls")

head(dataset_inicial, n = 5)
# Out:
#   Estudante   Tempo para chegar à escola (minutos)
# 1 Gabriela    15
# 2 Dalila      20
# 3 Gustavo     20
# 4 Letícia     40
# 5 Luiz Ovídio 50
#   Distância percorrida até a escola (quilômetros) Quantidade de semáforos
# 1  8                                              0
# 2  6                                              1
# 3 15                                              0
# 4 20                                              1
# 5 25                                              2
#   Período do dia Perfil ao volante
# 1 Manhã          calmo
# 2 Manhã          moderado
# 3 Manhã          moderado
# 4 Tarde          agressivo
# 5 Tarde          agressivo

# %%
dataset_inicial <- dataset_inicial %>% rename(observacoes = Observações)

head(dataset_inicial, n = 5)
# Out:
# Error in .f(.x[[i]], ...): objeto 'Observações' não encontrado
# Traceback:
#
# 1. dataset_inicial %>% rename(observacoes = Observações)
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. withVisible(function_list[[k]](value))
# 8. function_list[[k]](value)
# 9. rename(., observacoes = Observações)
# 10. rename.data.frame(., observacoes = Observações)
# 11. tidyselect::vars_rename(names(.data), !!!quos(...))
# 12. vars_rename_eval(quos, .vars)
# 13. map_if(quos, is_symbol, eval_tidy, data)
# 14. map(.x[sel], .f, ...)
# 15. .f(.x[[i]], ...)

# %% [markdown]
# # Dataset merge

# %%
dataset_merge <- read_excel("(1.3) Dataset Aula Data Wrangling (Join).xls")

head(dataset_merge, n = 5)
# Out:
#   Estudante Gênero
# 1 Gabriela  Feminino
# 2 Dalila    Feminino
# 3 Letícia   Feminino
# 4 Leonor    Feminino
# 5 Ana       Feminino

# %%
dataset_merge <- dataset_merge %>% rename(observacoes=Estudante)

# %% [markdown]
# #
